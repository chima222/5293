# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Assignment 2-3 Credit Model Data.xls")

# %%
df.head()
# Out:
#                                Company Name Exchange:Ticker S&P Entity ID  \
# 0                                 @Plan.Inc               -             -
# 1  01 Communique Laboratory Inc. (TSXV:ONE)        TSXV:ONE             -
# 2             024 Pharma, Inc. (OTCPK:EEIG)      OTCPK:EEIG             -
# 3                          0924885 B.C. Ltd               -             -
# 4                        1-800 AutoTow Inc.               -             -
#
#   EBITDA - Capital IQ [CY 2008] ($USDmm, Historical rate)  \
# 0                                                  -
# 1                                             -0.873
# 2                                             -0.497
# 3                                                  -
# 4                                                  -
#
#   EBITDA - Capital IQ [CY 2009] ($USDmm, Historical rate)  \
# 0                                                  -
# 1                                              -1.18
# ...
